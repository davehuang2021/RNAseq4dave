# %% [markdown]
# ## install

# %%
#setwd("/Users/m1/JobSkills/R/DEG/GSE117993/") 

# BiocManager::install("BiocStyle")
# BiocManager::install("limma")
# BiocManager::install("Glimma")
# BiocManager::install("tidyverse",force = TRUE)
# BiocManager::install("Mus.musculus",force = TRUE)
# BiocManager::install("Homo.sapiens",force = TRUE)
# BiocManager::install("dplyr",force = TRUE)
# BiocManager::install("GEOquery",force = TRUE)
# BiocManager::install("tidyverse")
# BiocManager::install("Homo.sapiens")

# BiocManager::install("openxlsx")

# BiocManager::install("BiocStyle")

# BiocManager::install("openxlsx")
# system("open .")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see 'help("repositories", package = "BiocManager")'
# for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.20 (BiocManager 1.30.26), R 4.4.2 (2024-10-31)
#
# Warning message:
# "package(s) not installed when version(s) same as or greater than current; use `force = TRUE` to re-install: 'openxlsx'"
# Old packages: 'Matrix', 'RSQLite', 'Rcpp', 'RcppArmadillo', 'XML', 'aplot', 'bookdown', 'boot', 'broom', 'curl',
#   'data.table', 'dbplyr', 'dtplyr', 'evaluate', 'future', 'gargle', 'ggplot2', 'googledrive', 'googlesheets4',
#   'hardhat', 'here', 'httr2', 'magrittr', 'pROC', 'parallelly', 'patchwork', 'pillar', 'progressr', 'purrr', 'ragg',
#   'restfulr', 'reticulate', 'rprojroot', 'rvest', 'scatterpie', 'stringr', 'textshaping', 'vroom', 'xfun', 'xml2',
#   'yulab.utils'

# %% [markdown]
# ## library

# %%
library(BiocStyle)
library(knitr)
options(digits=3)
options(width=120)

library(ggplot2)
library(limma)
library(Glimma)
library(edgeR)
# library(tximport)
library(GEOquery)
library(Homo.sapiens)
library(recount3)
library(DESeq2)
library(RColorBrewer)

library(tidyverse)
library(ggrepel)

library(pheatmap)
library(RColorBrewer)
# 返回：3种颜色的RGB值
library(hash)

library(tidyverse)

library(RColorBrewer)
library(ggrepel)
library(pheatmap)
library(clusterProfiler)

library(openxlsx)
library(dplyr)

# %% [markdown]
# ## read files

# %%
a <- system('ls ./')
b = 'a'
print(paste0(a,b))
a
# Out:
# [1] "0a"
# [1] 0
