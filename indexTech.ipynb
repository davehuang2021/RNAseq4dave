# %% [markdown]
# ## import

# %%
import pandas as pd
import scanpy as sc

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# pd         module    <module 'pandas' from '/o<...>ages/pandas/__init__.py'>
# sc         module    <module 'scanpy' from '/o<...>ages/scanpy/__init__.py'>
